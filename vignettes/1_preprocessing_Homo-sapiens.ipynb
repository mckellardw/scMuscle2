# %% [markdown]
# # Preprocessing of individual datasets

# %% [markdown]
# Import packages...
# - [scanpy](https://scanpy.readthedocs.io/en/stable/index.html)

# %%
import scanpy as sc
import scanpy.external as sce
import pandas as pd

import gc
import os

# %%
WORKDIR="/workdir/dwm269/scMuscle2"
os.chdir(WORKDIR)

# %%
from scripts.py.scantils import *
# from scripts.py.scanplots import *

# %%
gc.enable()

# %%
DATADIR="/workdir/dwm269/scMuscle2/data/align_out"

# %% [markdown]
# Scanpy settings info [[link](https://scanpy.readthedocs.io/en/stable/generated/scanpy._settings.ScanpyConfig.html)]

# %%
sc.settings.cachedir = './data/cache/'
sc.settings.n_jobs=16

# %% [markdown]
# Load metadata

# %%
meta = pd.read_csv("scMuscle2_metadata_v1-0.csv")
meta = meta.loc[meta["include"],] # remove unwanted metadata
meta = meta[[x in ["fastq", "bam"] for x in meta["file.format"]]] # remove samples w/ download issues

meta = meta[[x in ["muscle", "tendon"] for x in meta["tissue"]]] # subset by tissue 
meta = meta[[x in ["Homo sapiens"] for x in meta["species"]]] # subset by species , "Mus musculus"
meta = meta.iloc[[8,12,23,34,45],] # subset by row index

meta = meta[[x != "" for x in meta["GSM.accession"]]] # 
meta = meta[[x != "" for x in meta["sample"]]] # 

meta.index = list(range(0, len(meta))) # reset row indices
# meta

# %%
meta.tissue.value_counts()
# Out:
# muscle    4
# tendon    1
# Name: tissue, dtype: int64

# %% [markdown]
# Read in count data & initialize anndata objects. Also add metadata to each object

# %%
# try:
#     scm_list.index
# except:
scm_list = pd.Series(
    index = meta["GSM.accession"],
    data = [""]*meta.shape[0]
)

# %%
for i in range(0,meta.shape[0]):
    if os.path.exists(DATADIR+"/"+meta["GSM.accession"][i]+"/STARsolo/Solo.out/GeneFull/filtered/matrix.mtx.gz"):
        print("Sample: " + meta["GSM.accession"][i]) 
#         try:
        scm_list[i] = sc.read_10x_mtx(
                path=DATADIR+"/"+meta["GSM.accession"][i]+"/STARsolo/Solo.out/GeneFull/filtered", 
                var_names='gene_symbols',
                make_unique=True,
                cache=True
            )
          
        scm_list[i].var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`

        for j in range(0,meta.shape[1]): #metadata features
            scm_list[i].obs[meta.columns[j]] = meta.iloc[i,j]

        scm_list[i].layers['counts'] = scm_list[i].X # save counts as a layer for future plotting

        print("     Loaded " + str(scm_list[i].shape[0]) + " cells and " + str(scm_list[i].shape[1]) + " genes...")
    else:
        print("Can't find counts for " + str(meta["GSM.accession"][i]) + "...")
#         except:
#             print("Exception with " + meta["sample"][i])
# Out:
# Sample: GSM5848681
# /home/dwm269/miniconda3/envs/scm2/lib/python3.10/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
#      Loaded 5499 cells and 62703 genes...
# Sample: GSM4272893
# /home/dwm269/miniconda3/envs/scm2/lib/python3.10/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
#      Loaded 2393 cells and 62703 genes...
# Sample: GSM5098738
# /home/dwm269/miniconda3/envs/scm2/lib/python3.10/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
#      Loaded 7737 cells and 62703 genes...
# Sample: GSM5098749
# /home/dwm269/miniconda3/envs/scm2/lib/python3.10/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
#      Loaded 3802 cells and 62703 genes...
# Sample: GSM4743496
#      Loaded 3963 cells and 62703 genes...
# /home/dwm269/miniconda3/envs/scm2/lib/python3.10/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(

# %% [markdown]
# Add ambient-RNA-scrubbed counts

# %%
#TODO

# %%
gc.collect()
# Out:
# 1422

# %% [markdown]
# QC filter and preprocess individual datasets

# %%
# gene/transcript, mito filters count filters
for i in range(0,meta.shape[0]):
    try:
        print(meta["GSM.accession"][i] + ': ' + str(scm_list[i].shape[0]) + " cells and " + str(scm_list[i].shape[1]) +' features...')  

        # Hard filters for feature and UMI counts
        sc.pp.filter_cells(
            scm_list[i],
            min_genes=500
        )
        sc.pp.filter_cells(
            scm_list[i], 
            min_counts=1000
        )

        scm_list[i].var['mito'] = scm_list[i].var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
        sc.pp.calculate_qc_metrics(
            scm_list[i], 
            qc_vars=['mito'], 
            percent_top=None, 
            log1p=False, 
            inplace=True
        )  

        # QC filter(s)
        scm_list[i] = scm_list[i][scm_list[i].obs.pct_counts_mito < 40, :] 

        print('After filtering: ' + str(scm_list[i].shape[0]) + " cells and " + str(scm_list[i].shape[1]) +' features...')  
    
    except:
            print("Exception with " + str(meta["GSM.accession"][i]))
        
    print(" ")
# Out:
# GSM4743488: 4788 cells and 61860 features...
# After filtering: 3004 cells and 61860 features...
#
# GSM4743489: 3153 cells and 61860 features...
# After filtering: 1814 cells and 61860 features...
#
# GSM4743490: 3050 cells and 61860 features...
# After filtering: 2232 cells and 61860 features...
#
# GSM4743491: 2505 cells and 61860 features...
# After filtering: 1870 cells and 61860 features...
#
# GSM4743492: 2174 cells and 61860 features...
# After filtering: 1936 cells and 61860 features...
#
# GSM4743493: 2643 cells and 61860 features...
# After filtering: 2485 cells and 61860 features...
#
# GSM4743494: 2706 cells and 61860 features...
# After filtering: 2578 cells and 61860 features...
#
# GSM4743495: 3207 cells and 61860 features...
# After filtering: 2532 cells and 61860 features...
#
# GSM5848681: 5500 cells and 61860 features...
# After filtering: 5274 cells and 61860 features...
#
# GSM5848680: 5875 cells and 61860 features...
# After filtering: 5234 cells and 61860 features...
#
# GSM5848679: 6432 cells and 61860 features...
# After filtering: 6002 cells and 61860 features...
#
# GSM5848678: 10059 cells and 61860 features...
# After filtering: 9882 cells and 61860 features...
#
# GSM4272893: 2395 cells and 61860 features...
# After filtering: 1689 cells and 61860 features...
#
# GSM4272894: 902 cells and 61860 features...
# After filtering: 726 cells and 61860 features...
#
# GSM4272895: 1676 cells and 61860 features...
# After filtering: 1195 cells and 61860 features...
#
# GSM4272896: 382 cells and 61860 features...
# After filtering: 253 cells and 61860 features...
#
# GSM4272897: 2142 cells and 61860 features...
# After filtering: 921 cells and 61860 features...
#
# GSM4272898: 6601 cells and 61860 features...
# After filtering: 5615 cells and 61860 features...
#
# GSM4272899: 2799 cells and 61860 features...
# After filtering: 2565 cells and 61860 features...
#
# GSM4272900: 5430 cells and 61860 features...
# After filtering: 4845 cells and 61860 features...
#
# GSM4272901: 13524 cells and 61860 features...
# After filtering: 9551 cells and 61860 features...
#
# GSM4272902: 9916 cells and 61860 features...
# After filtering: 7760 cells and 61860 features...
#
# GSM5098737: 6440 cells and 61860 features...
# After filtering: 3587 cells and 61860 features...
#
# GSM5098738: 7748 cells and 61860 features...
# After filtering: 5203 cells and 61860 features...
#
# GSM5098739: 4335 cells and 61860 features...
# After filtering: 3030 cells and 61860 features...
#
# GSM5098740: 14670 cells and 61860 features...
# After filtering: 1556 cells and 61860 features...
#
# GSM5098741: 6059 cells and 61860 features...
# After filtering: 3208 cells and 61860 features...
#
# GSM5098742: 5780 cells and 61860 features...
# After filtering: 2695 cells and 61860 features...
#
# GSM5098743: 4232 cells and 61860 features...
# After filtering: 1451 cells and 61860 features...
#
# GSM5098744: 4037 cells and 61860 features...
# After filtering: 1515 cells and 61860 features...
#
# GSM5098745: 9432 cells and 61860 features...
# After filtering: 5177 cells and 61860 features...
#
# GSM5098746: 4778 cells and 61860 features...
# After filtering: 3750 cells and 61860 features...
#
# GSM5098747: 4128 cells and 61860 features...
# After filtering: 2692 cells and 61860 features...
#
# GSM5098748: 5410 cells and 61860 features...
# After filtering: 4066 cells and 61860 features...
#
# GSM5098749: 3799 cells and 61860 features...
# After filtering: 3041 cells and 61860 features...
#
# GSM5098750: 3429 cells and 61860 features...
# After filtering: 2037 cells and 61860 features...
#
# GSM5098751: 13305 cells and 61860 features...
# After filtering: 9348 cells and 61860 features...
#
# GSM5098752: 12866 cells and 61860 features...
# After filtering: 8155 cells and 61860 features...
#
# GSM5098753: 17689 cells and 61860 features...
# After filtering: 11387 cells and 61860 features...
#
# GSM5672476: 10032 cells and 61860 features...
# After filtering: 7799 cells and 61860 features...
#
# GSM5672477: 8612 cells and 61860 features...
# After filtering: 6644 cells and 61860 features...
#
# GSM5672478: 8448 cells and 61860 features...
# After filtering: 6673 cells and 61860 features...
#
# GSM5672479: 6448 cells and 61860 features...
# After filtering: 5622 cells and 61860 features...
#
# GSM5672480: 8972 cells and 61860 features...
# After filtering: 8467 cells and 61860 features...
#
# GSM5390515: 8297 cells and 61860 features...
# After filtering: 8127 cells and 61860 features...
#
# GSM4743496: 3938 cells and 61860 features...
# After filtering: 2273 cells and 61860 features...
#
# GSM5390456: 4017 cells and 61860 features...
# After filtering: 3788 cells and 61860 features...
#
# GSM5390460: 7282 cells and 61860 features...
# After filtering: 4597 cells and 61860 features...
#
# GSM5390463: 8770 cells and 61860 features...
# After filtering: 7909 cells and 61860 features...
#
# GSM5390474: 7369 cells and 61860 features...
# After filtering: 6617 cells and 61860 features...
#
# GSM5848676: 11025 cells and 61860 features...
# After filtering: 10495 cells and 61860 features...
#
# GSM5848675: 20391 cells and 61860 features...
# After filtering: 16981 cells and 61860 features...
#
# GSM5848674: 4659 cells and 61860 features...
# After filtering: 3559 cells and 61860 features...
#
# GSM5848673: 11505 cells and 61860 features...
# After filtering: 10724 cells and 61860 features...
#
# GSM5390475: 8261 cells and 61860 features...
# After filtering: 8091 cells and 61860 features...
#
# GSM5390476: 9575 cells and 61860 features...
# After filtering: 7146 cells and 61860 features...
#
# GSM5390477: 4824 cells and 61860 features...
# After filtering: 4524 cells and 61860 features...
#
# GSM5390478: 5368 cells and 61860 features...
# After filtering: 5036 cells and 61860 features...
#
# GSM5390479: 5018 cells and 61860 features...
# After filtering: 4879 cells and 61860 features...
#
# GSM5390480: 5256 cells and 61860 features...
# After filtering: 4944 cells and 61860 features...
#
# GSM5390481: 10425 cells and 61860 features...
# After filtering: 7726 cells and 61860 features...
#
# GSM5390483: 6181 cells and 61860 features...
# After filtering: 6039 cells and 61860 features...
#
# GSM5390489: 5731 cells and 61860 features...
# After filtering: 5632 cells and 61860 features...
#
# GSM5390490: 5183 cells and 61860 features...
# After filtering: 5112 cells and 61860 features...
#
# GSM5848693: 6310 cells and 61860 features...
# After filtering: 5129 cells and 61860 features...
#
# GSM5848694: 6545 cells and 61860 features...
# After filtering: 3644 cells and 61860 features...
#
# GSM5848692: 15213 cells and 61860 features...
# After filtering: 15080 cells and 61860 features...
#
# GSM5848691: 10253 cells and 61860 features...
# After filtering: 10132 cells and 61860 features...
#
# GSM5848690: 7438 cells and 61860 features...
# After filtering: 6296 cells and 61860 features...
#
# GSM5848689: 6182 cells and 61860 features...
# After filtering: 5571 cells and 61860 features...
#
# GSM5848688: 16898 cells and 61860 features...
# After filtering: 14178 cells and 61860 features...
#
# GSM5848687: 6087 cells and 61860 features...
# After filtering: 5081 cells and 61860 features...
#
# GSM5848685: 13200 cells and 61860 features...
# After filtering: 8498 cells and 61860 features...
#
# GSM5848686: 18405 cells and 61860 features...
# After filtering: 15451 cells and 61860 features...
#
# GSM5848684: 20133 cells and 61860 features...
# After filtering: 19204 cells and 61860 features...
#
# GSM5848683: 8076 cells and 61860 features...
# After filtering: 7503 cells and 61860 features...
#
# GSM5848682: 5988 cells and 61860 features...
# After filtering: 4012 cells and 61860 features...
#
# GSM4979413: 2672 cells and 61860 features...
# After filtering: 2060 cells and 61860 features...
#
# GSM4979414: 2875 cells and 61860 features...
# After filtering: 2306 cells and 61860 features...
#
# GSM4979415: 3520 cells and 61860 features...
# After filtering: 2852 cells and 61860 features...
#
# GSM4979416: 2898 cells and 61860 features...
# After filtering: 2445 cells and 61860 features...
#
# GSM4979417: 3786 cells and 61860 features...
# After filtering: 3152 cells and 61860 features...
#
# GSM4979418: 2799 cells and 61860 features...
# After filtering: 2297 cells and 61860 features...
#
# Exception with nan
#
# Exception with nan
#
# Exception with nan
#
# Exception with nan
#
# Exception with nan

# %% [markdown]
# Add metadata to each object

# %% [markdown]
# ## Doublet removal via Scrublet

# %% [markdown]
# Estimate doublet scores

# %%
# sc.settings.set_figure_params(
#     fontsize=8
# )

# for i in range(0,meta.shape[0]):
#     try:
#         sc.external.pp.scrublet(
#             scm_list[i]
#         )
#         sc.external.pl.scrublet_score_distribution(
#             scm_list[i],
#             figsize =[6,2.25]
#         )
            
#     except:
#             print("Exception with " + meta["sample"][i])
        
#     print(" ")

# %% [markdown]
# Estimate doublet score cutoff values for each sample

# %%
# cutoff_threshold = [
#     0.63, 0.63, 
#     0.59, #D4_200um
#     0.52, 
#     0.6, #D4_1000um
#     0.24, 
#     0.2, 0.24,
# #     0.58, # D20_600um
#     0.63, # D21_200um
#     0.18,
#     0.18 #D21_1000um
# ]

# %%
# scm_list

# %%
# print("Final cell & feature counts:\n")
# for i in range(0,meta.shape[0]):    
#     scm_list[i] = scm_list[i][scm_list[i].obs["doublet_score"] < cutoff_threshold[i],]
#     print(meta["sample"][i] + ': ' + str(scm_list[i].shape[0]) + " cells and " + str(scm_list[i].shape[1]) +' features...')  
#     print("")

# %% [markdown]
# ## Merge into a single AnnData object and preprocess

# %%
scm = scm_list[0].concatenate(
    scm_list[1:],
    index_unique=None
#     join="inner"
#     batch_key="sample",
    # batch_categories=meta["GSM.accession"]
)
scm.obs_names_make_unique()
print(scm.shape)
# Out:
# /home/dwm269/miniconda3/envs/scm2/lib/python3.10/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/dwm269/miniconda3/envs/scm2/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# (23394, 62703)
# /home/dwm269/miniconda3/envs/scm2/lib/python3.10/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %% [markdown]
# QC plotting

# %%
sc.settings.set_figure_params(
    fontsize=8,
    figsize=[18,4]
)

sc.pl.violin(
    scm,
    size=0.5,
    rotation=90,
#     log=True,
    keys=['pct_counts_mito'],# '',''],
    stripplot=False,
    groupby='GSM.accession'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 6
#       1 sc.settings.set_figure_params(
#       2     fontsize=8,
#       3     figsize=[18,4]
#       4 )
# ----> 6 sc.pl.violin(
#       7     scm,
#       8     size=0.5,
#       9     rotation=90,
#      10 #     log=True,
#      11     keys=['pct_counts_mito'],# '',''],
#      12     stripplot=False,
#      13     groupby='GSM.accession'
#      14 )
#
# File ~/miniconda3/envs/scm2/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:769, in violin(adata, keys, groupby, log, use_raw, stripplot, jitter, size, layer, scale, order, multi_panel, xlabel, ylabel, rotation, show, save, ax, **kwds)
#     763     raise ValueError(
#     764         f'Expected number of y-labels to be `{len(keys)}`, '
#     765         f'found `{len(ylabel)}`.'
#     766     )
#     768 if groupby is not None:
# --> 769     obs_df = get.obs_df(adata, keys=[groupby] + keys, layer=layer, use_raw=use_raw)
#     770     if kwds.get('palette', None) is None:
#     771         if not is_categorical_dtype(adata.obs[groupby]):
#
# File ~/miniconda3/envs/scm2/lib/python3.10/site-packages/scanpy/get/get.py:272, in obs_df(adata, keys, obsm_keys, layer, gene_symbols, use_raw)
#     269 else:
#     270     alias_index = None
# --> 272 obs_cols, var_idx_keys, var_symbols = _check_indices(
#     273     adata.obs,
#     274     var.index,
#     275     "obs",
#     276     keys,
#     277     alias_index=alias_index,
#     278     use_raw=use_raw,
#     279 )
#     281 # Make df
#     282 df = pd.DataFrame(index=adata.obs_names)
#
# File ~/miniconda3/envs/scm2/lib/python3.10/site-packages/scanpy/get/get.py:167, in _check_indices(dim_df, alt_index, dim, keys, alias_index, use_raw)
#     165         not_found.append(key)
#     166 if len(not_found) > 0:
# --> 167     raise KeyError(
#     168         f"Could not find keys '{not_found}' in columns of `adata.{dim}` or in"
#     169         f" {alt_repr}.{alt_search_repr}."
#     170     )
#     172 return col_keys, index_keys, index_aliases
#
# KeyError: "Could not find keys '['pct_counts_mito']' in columns of `adata.obs` or in adata.var_names."

# %% [markdown]
# Preprocessing...

# %%
sc.pp.normalize_total(
    scm, 
    target_sum=1e4
)

sc.pp.log1p(
    scm
)

sc.pp.highly_variable_genes(
    scm,
    subset=False
)

# %%
sc.pp.scale(
    scm
)
sc.tl.pca(
    scm, 
    svd_solver='arpack',
    n_comps=50
)

# %%
scm.shape

# %%
sc.pp.neighbors(
    scm,
    n_pcs = npcs(scm, reduction="X_pca"),
    n_neighbors = 50
)

# %%
sc.tl.umap(
    scm
#     group_by ="neighbors"
)

# %%
sc.set_figure_params(
    figsize=(6,6),
    dpi=200
)
sc.pl.umap(
    scm,
    legend_loc = None,
    color =["GSM.accession"] #GSM.accession
)

# %%
gc.collect()

# %% [markdown]
# Add cell cycle inference

# %%
# load in cell cycle genes lists
s_genes = list(pd.read_csv("resources/gene_lists/seurat_s_genes_2019.csv")['x'])
g2m_genes = list(pd.read_csv("resources/gene_lists/seurat_g2m_genes_2019.csv")['x'])

# score and plot
sc.tl.score_genes_cell_cycle(
    scm, 
    s_genes=s_genes, 
    g2m_genes=g2m_genes, 
    use_raw=False
)

# %% [markdown]
# Save merged anndata object for easy loading

# %%
# Save h5ad object for subsequent python analyses
scm.write("data/pyobjs/homo_sapiens_v1.h5ad")
