# %%
### Annotate cell types in mouse harmony-integrated atlas

# %%
import scanpy as sc
import scanpy.external as sce
import pandas as pd

import random
import gc
import os
import seaborn as sns

# %%
WORKDIR="/workdir/dwm269/scMuscle2"
os.chdir(WORKDIR)

# %%
gc.enable()

# %%
NCORES=16
sc.settings.n_jobs = NCORES

# %%
from scripts.py.scantils import *
# from scripts.py.scanplots import *

# %%
mouse = sc.read_h5ad("data/atlas/mus_musculus_pp_harmony.h5ad")
mouse.shape
# Out:
# (1538623, 433)

# %%
scm_genes = pd.read_csv("resources/gene_lists/scMuscle_markers_v1.txt", header=None)[0].tolist()

# %%
[gene for gene in scm_genes if gene not in mouse.var_names]
# Out:
# ['Ptprc',
#  'Igkc',
#  'Cd8a',
#  'Cd4',
#  'Cd27',
#  'Tbx21',
#  'Klra7',
#  'S100a8',
#  'Cxcr4',
#  'Ctsa',
#  'Ctsb',
#  'Ctsl',
#  'Ctsz',
#  'Fabp5',
#  'Cx3cr1',
#  'Ccr2',
#  'Itgam',
#  'Tgfbi',
#  'Mapk14',
#  'Ctss',
#  'Fcgr3',
#  'Csf1r',
#  'C1qa',
#  'Cd74',
#  'Cd83',
#  'Flt3',
#  'Cd209a',
#  'Xcr1',
#  'Pecam1',
#  'Cdh5',
#  'Apln',
#  'Aplnr',
#  'Kdr',
#  'Cxcl12',
#  'Lpl',
#  'Ly6a',
#  'Fbln5',
#  'Hey1',
#  'Alpl',
#  'Lrg1',
#  'Icam1',
#  'Hif1a',
#  'Vwf',
#  'Pdgfrb',
#  'Cspg4',
#  'Mcam',
#  'Acta2',
#  'Pdgfra',
#  'Cd34',
#  'Thy1',
#  'Tnfaip6',
#  'Igfbp5',
#  'Dpp4',
#  'Cd164',
#  'Bmp1',
#  'Il33',
#  'Egfr',
#  'Mmp2',
#  'Mmp14',
#  'Ctsk',
#  'Adam12',
#  'Bmp5',
#  'Myoc',
#  'Col1a1',
#  'Col3a1',
#  'Dcn',
#  'Gsn',
#  'Bgn',
#  'Apod',
#  'Hdlbp',
#  'Dio2',
#  'Rspo3',
#  'Scx',
#  'Cd9',
#  'Itga7',
#  'Vcam1',
#  'Sdc4',
#  'Pax7',
#  'Myf5',
#  'Myod1',
#  'Cdkn1a',
#  'Gm7325',
#  'Tmem8c',
#  'Dmd',
#  'Tnnt3',
#  'Acta1',
# ...

# %%
sc.pl.dotplot(
    mouse, 
    [gene for gene in scm_genes if gene in mouse.var_names], 
    groupby=f"harmony_{1.2}",
    cmap="plasma"
)
# Out:
# /home/dwm269/miniconda3/envs/scm2/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)
