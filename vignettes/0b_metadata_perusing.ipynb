# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
WORKDIR="/workdir/dwm269/scMuscle2"
os.chdir(WORKDIR)

# %%
meta = pd.read_csv("scMuscle2_metadata_v1-0.csv")

meta = meta.loc[meta["include"],] # remove unwanted metadata
meta = meta[[x in ["Homo sapiens", "Mus musculus"] for x in meta["species"]]]                       # subset by species 

meta = meta[list(meta["file.format"]!="ERR")]                                                       # remove samples with file format issues
meta = meta[list(meta["file.format"]!="ngdc_fastq")]                                                # remove samples with file format issues

meta = meta[list(meta["GSM.accession"]!="NA")]
meta = meta[list(meta["GSM.accession"]!="")]
meta = meta[[x in ["3p_v2", "3p_v3", "3p_v3.1", "5p_v1"] for x in meta["chemistry"]]]               # subset out 10x Genomics' chemistries
meta = meta[[x in ["muscle", "tendon","limb", "ligament", "cartilage"] for x in meta["tissue"]]]    # subset tissues of interest

# %%
meta
# Out:
#            source.label                         sample description  tissue  \
# 0     Tabula Muris 2018                       10X_P4_0         NaN  muscle
# 1     Tabula Muris 2018                       10X_P4_1         NaN  muscle
# 3     Tabula Muris 2018                      10X_P7_10         NaN  muscle
# 4     Tabula Muris 2018                      10X_P7_14         NaN  muscle
# 5     Tabula Muris 2018                      10X_P7_15         NaN  muscle
# ...                 ...                            ...         ...     ...
# 1111        Fuiten 2023   Day 2, replicate B, scRNAseq         NaN    limb
# 1112        Fuiten 2023   Day 7, replicate A, scRNAseq         NaN    limb
# 1113        Fuiten 2023   Day 7, replicate B, scRNAseq         NaN    limb
# 1114        Fuiten 2023  Day 10, replicate A, scRNAseq         NaN    limb
# 1115        Fuiten 2023  Day 10, replicate B, scRNAseq         NaN    limb
#
#      subtissue                                           comments  include  \
# 0       tongue                                                NaN     True
# 1       tongue                                                NaN     True
# 3       tongue                                                NaN     True
# 4     hindlimb                                                NaN     True
# 5     hindlimb                                                NaN     True
# ...        ...                                                ...      ...
# 1111  in vitro                                                NaN     True
# 1112  in vitro  index read treated as R1, R1 treated as R2, R2...     True
# 1113  in vitro  index read treated as R1, R1 treated as R2, R2...     True
# 1114  in vitro  index read treated as R1, R1 treated as R2, R2...     True
# 1115  in vitro  index read treated as R1, R1 treated as R2, R2...     True
#
#       ambient.decon       species GSE.accession  ... sample.accession  \
# 0              True  Mus musculus     GSE109774  ...              NaN
# 1              True  Mus musculus     GSE109774  ...              NaN
# 3              True  Mus musculus     GSE109774  ...              NaN
# 4              True  Mus musculus     GSE109774  ...       SRS3044258
# 5              True  Mus musculus     GSE109774  ...       SRS3044259
# ...             ...           ...           ...  ...              ...
# 1111           True  Mus musculus     GSE221883  ...              NaN
# 1112           True  Mus musculus     GSE221883  ...              NaN
# 1113           True  Mus musculus     GSE221883  ...              NaN
# 1114           True  Mus musculus     GSE221883  ...              NaN
# 1115           True  Mus musculus     GSE221883  ...              NaN
#
#      SAMN.accession                                      file.checksum  \
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 3               NaN                                                NaN
# 4               NaN  ftp://ftp.sra.ebi.ac.uk/vol1/SRA653/SRA653146/...
# 5               NaN  ftp://ftp.sra.ebi.ac.uk/vol1/SRA653/SRA653146/...
# ...             ...                                                ...
# 1111            NaN                                                NaN
# 1112            NaN                                                NaN
# 1113            NaN                                                NaN
# 1114            NaN                                                NaN
# 1115            NaN                                                NaN
#
#      other.accession                      source manuscript.doi  \
# 0                NaN                         NaN            NaN
# 1                NaN                         NaN            NaN
# 3                NaN                         NaN            NaN
# 4                NaN  Tabula Muris, Nature, 2018            NaN
# 5                NaN  Tabula Muris, Nature, 2018            NaN
# ...              ...                         ...            ...
# 1111             NaN                         NaN            NaN
# 1112             NaN                         NaN            NaN
# 1113             NaN                         NaN            NaN
# 1114             NaN                         NaN            NaN
# 1115             NaN                         NaN            NaN
#
#                               manuscript.pubmed  experiment.instrument  \
# 0                                           NaN                    NaN
# 1                                           NaN                    NaN
# 3                                           NaN                    NaN
# 4     https://pubmed.ncbi.nlm.nih.gov/30283141/  Illumina NovaSeq 6000
# 5     https://pubmed.ncbi.nlm.nih.gov/30283141/  Illumina NovaSeq 6000
# ...                                         ...                    ...
# 1111                                        NaN                    NaN
# 1112                                        NaN                    NaN
# 1113                                        NaN                    NaN
# 1114                                        NaN                    NaN
# 1115                                        NaN                    NaN
#
#                                             study.title  \
# 0                                                   NaN
# 1                                                   NaN
# 3                                                   NaN
# 4     Tabula Muris: Transcriptomic characterization ...
# 5     Tabula Muris: Transcriptomic characterization ...
# ...                                                 ...
# 1111                                                NaN
# 1112                                                NaN
# 1113                                                NaN
# 1114                                                NaN
# 1115                                                NaN
#
#                                          study.abstract
# 0                                                   NaN
# 1                                                   NaN
# 3                                                   NaN
# 4     We have created a resource of single cell tran...
# 5     We have created a resource of single cell tran...
# ...                                                 ...
# 1111                                                NaN
# 1112                                                NaN
# 1113                                                NaN
# 1114                                                NaN
# 1115                                                NaN
#
# [549 rows x 27 columns]

# %% [markdown]
# ## Stacked bar chart showing species & chemistry

# %%
# Prepare the data for the stacked bar chart
stacked_data = meta.groupby(['species', 'chemistry']).size().reset_index(name='count')

# Plot the stacked bar chart
plt.figure(figsize=(10, 6))
sns.barplot(
    x='species', 
    y='count',
    hue='chemistry',
    data=stacked_data
)

plt.title('Stacked Bar Chart')
plt.xlabel('Species')
plt.ylabel('Number of samples')

plt.show()
